# %%
from utilities.jsonRW import readJSON, delete_agent_data_by_id

# %%
shape = "5x5"               # "5x5" or "14x14"
algorithm = "Q-Learning"    # "Q-Learning" or "DQN" or "DDQN"

readJSON(algorithm, shape)

# %%
##delete_agent_data_by_id("Q-Learning", shape, 3)
