# %%
from utilities.jsonRW import readJSON, readJSONById, display_agent_data, delete_agent_data_by_id

# %%
shape = "14x14"               # "5x5" or "14x14"
algorithm = "DQN"    # "Q-Learning" or "DQN" or "DDQN"

# %%
#readJSON(algorithm, shape)

# %%
#readJSONById(algorithm, shape, 1)

# %%
#for i in (19,17):
    
    #delete_agent_data_by_id(algorithm, shape, i)
# Out:
# Agent data with ID 19 has been successfully deleted.
# Agent data with ID 17 has been successfully deleted.

# %%
display_agent_data(algorithm, shape, 1)
# Out:
# Displaying entries 1 to 10 (out of 17):
