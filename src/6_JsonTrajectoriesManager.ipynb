# %%
from utilities.jsonRW import readJSON, readJSONById, display_agent_data, delete_agent_data_by_id

# %%
shape = "14x14"               # "5x5" or "14x14"
algorithm = "DDQN"    # "Q-Learning" or "DQN" or "DDQN"

# %%
readJSON(algorithm, shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\el_sa\Desktop\proyectoNN_salva\src\6_JsonTrajectoriesManager.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/src/6_JsonTrajectoriesManager.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> readJSON(algorithm, shape)
#
# File c:\Users\el_sa\Desktop\proyectoNN_salva\src\utilities\jsonRW.py:92, in readJSON(algorithm, shape)
#      89 #print(f'Agent {id} info --> Algorithm: {algorithm}   Shape: {shape}   Episodes: {episodes}   Max steps: {max_steps}')
#      91 fig = plot_trajectory(string_policy_grid, starting_position, id)
# ---> 92 fig.suptitle(f'Agent {id} - {algorithm}  Start pos: {starting_position}  Episodes: {episodes}  Max steps: {max_steps}')
#      93 plt.show()
#
# AttributeError: 'NoneType' object has no attribute 'suptitle'

# %%
#readJSONById(algorithm, shape, 1)

# %%
#for i in (19,17):
    
#delete_agent_data_by_id(algorithm, shape, 2)
# Out:
# Agent data with ID 2 has been successfully deleted.

# %%
display_agent_data(algorithm, shape, 1)
# Out:
# Displaying entries 1 to 10 (out of 65):
