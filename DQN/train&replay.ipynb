# %%
# %matplotlib inline

# %%
from DQNagentClass import Agent
import matplotlib.pyplot as plt
import numpy as np
import torch
import gymnasium as gym

# %%
#Maze config
maze = [
    ['.', '.', '#', '.', 'G'],
    ['.', '.', '#', '.', '.'],
    ['.', '.', '.', '.', '.'],
    ['.', '.', '#', '.', '.'],
    ['S', '.', '#', '.', '.'],
]

grid_model_path = '../data/models/modelo_entorno.h5'
reward_model_path = '../data/models/modelo_reward.h5'

gym.register(id='grid-v0', entry_point='NNmodeledEnv:NNGridWorldEnv')
env = gym.make('grid-v0', maze=maze, grid_model_path=grid_model_path, reward_model_path=reward_model_path)
# Out:
# Loading models...
# Models loaded
# c:\Users\el_sa\anaconda3\envs\TFG\Lib\site-packages\gymnasium\envs\registration.py:694: UserWarning: WARN: Overriding environment grid-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
def dqn(agent, n_episodes = 100, max_t = 1000, eps_start = 1.0, eps_end = 0.01, eps_decay = 0.996):
    """Deep Q-Learning
    Params
    ======
        n_episodes (int): maximum number of training epsiodes
        max_t (int): maximum number of timesteps per episode
        eps_start (float): starting value of epsilon, for epsilon-greedy action selection
        eps_end (float): minimum value of epsilon 
        eps_decay (float): mutiplicative factor (per episode) for decreasing epsilon
        
    """
    scores = [] # list containing score from each episode
    durations = [] # list containing duration of each episode
    eps = eps_start

    for i_episode in range(1, n_episodes+1):
        state,_ = env.reset()
        score = 0
        for t in range(1, max_t+1):
            action = agent.act(state,eps)
            #print("State: ", state,"Action: ",action)
            next_state,reward,done,_,_ = env.step(action)
            agent.step(state,action,reward,next_state,done)
            ## above step decides whether we will train(learn) the network actor (local_qnetwork) or we will fill the replay buffer
            ## if len replay buffer is equal to the batch size then we will train the network or otherwise we will add experience tuple in our replay buffer.
            state = next_state
            score += reward

            if done or t == max_t:
                print('Episode: {}\tSteps: {}'.format(i_episode,t))
                scores.append(score)
                durations.append(t)
                break

            eps = max(eps*eps_decay,eps_end)## decrease the epsilon

            if np.mean(scores)>=10.0:
                print('\nEnvironment solve in {:d} epsiodes!\tAverage score: {:.2f}'.format(i_episode-100, np.mean(scores)))
                torch.save(agent.qnetwork_local.state_dict(),'checkpoint.pth')
                break

    return scores, durations

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#print(device)
#print(env.action_space.n, env.observation_space.shape[0])

#Si cambio los seed de los agentes superan muchas veces el max_t de 200
dqnagent1 = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
dqnagent2 = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
dqnagent3 = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
dqnagent4 = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
dqnagent5 = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)

agents_arr = [dqnagent1, dqnagent2, dqnagent3, dqnagent4, dqnagent5]
scores_arr = []
durations_arr = []
# Out:
# cuda:0
# 4 2

# %%
#TRAINING
for agent in agents_arr:
    print("Agent", agents_arr.index(agent)+1,"/",len(agents_arr))
    scores, durations = dqn(agent)
    scores_arr.append(scores)
    durations_arr.append(durations)
# Out:
# Agent 1 / 5
# Episode: 1	Steps: 236
# Episode: 2	Steps: 58
# Episode: 3	Steps: 120
# Episode: 4	Steps: 38
# Episode: 5	Steps: 62
# Episode: 6	Steps: 43
# Episode: 7	Steps: 1000
# Episode: 8	Steps: 174
# Episode: 9	Steps: 8
# Episode: 10	Steps: 112
# Episode: 11	Steps: 8
# Episode: 12	Steps: 8
# Episode: 13	Steps: 8
# Episode: 14	Steps: 84
# Episode: 15	Steps: 8
# Episode: 16	Steps: 8
# Episode: 17	Steps: 8
# Episode: 18	Steps: 8
# Episode: 19	Steps: 72
# Episode: 20	Steps: 20
# Episode: 21	Steps: 8
# Episode: 22	Steps: 36
# Episode: 23	Steps: 8
# Episode: 24	Steps: 24
# Episode: 25	Steps: 148
# Episode: 26	Steps: 8
# Episode: 27	Steps: 84
# Episode: 28	Steps: 8
# Episode: 29	Steps: 8
# Episode: 30	Steps: 8
# Episode: 31	Steps: 72
# Episode: 32	Steps: 8
# Episode: 33	Steps: 144
# Episode: 34	Steps: 8
# Episode: 35	Steps: 8
# Episode: 36	Steps: 92
# Episode: 37	Steps: 8
# Episode: 38	Steps: 72
# Episode: 39	Steps: 8
# Episode: 40	Steps: 8
# Episode: 41	Steps: 8
# Episode: 42	Steps: 8
# Episode: 43	Steps: 8
# Episode: 44	Steps: 68
# Episode: 45	Steps: 8
# Episode: 46	Steps: 8
# Episode: 47	Steps: 8
# Episode: 48	Steps: 68
# Episode: 49	Steps: 8
# Episode: 50	Steps: 8
# Episode: 51	Steps: 8
# Episode: 52	Steps: 8
# Episode: 53	Steps: 72
# Episode: 54	Steps: 8
# Episode: 55	Steps: 8
# Episode: 56	Steps: 8
# Episode: 57	Steps: 8
# Episode: 58	Steps: 9
# Episode: 59	Steps: 51
# Episode: 60	Steps: 8
# Episode: 61	Steps: 8
# Episode: 62	Steps: 8
# Episode: 63	Steps: 56
# Episode: 64	Steps: 8
# Episode: 65	Steps: 8
# Episode: 66	Steps: 8
# Episode: 67	Steps: 8
# Episode: 68	Steps: 60
# Episode: 69	Steps: 8
# Episode: 70	Steps: 8
# Episode: 71	Steps: 8
# Episode: 72	Steps: 8
# Episode: 73	Steps: 52
# Episode: 74	Steps: 8
# Episode: 75	Steps: 8
# Episode: 76	Steps: 8
# Episode: 77	Steps: 60
# Episode: 78	Steps: 8
# Episode: 79	Steps: 8
# Episode: 80	Steps: 40
# Episode: 81	Steps: 8
# Episode: 82	Steps: 8
# Episode: 83	Steps: 8
# Episode: 84	Steps: 44
# Episode: 85	Steps: 8
# Episode: 86	Steps: 8
# Episode: 87	Steps: 8
# Episode: 88	Steps: 36
# Episode: 89	Steps: 8
# Episode: 90	Steps: 8
# Episode: 91	Steps: 8
# Episode: 92	Steps: 52
# Episode: 93	Steps: 8
# Episode: 94	Steps: 8
# Episode: 95	Steps: 8
# Episode: 96	Steps: 48
# Episode: 97	Steps: 8
# Episode: 98	Steps: 8
# Episode: 99	Steps: 48
# Episode: 100	Steps: 8
# Agent 2 / 5
# Episode: 1	Steps: 318
# Episode: 2	Steps: 160
# Episode: 3	Steps: 140
# Episode: 4	Steps: 835
# Episode: 5	Steps: 66
# Episode: 6	Steps: 86
# Episode: 7	Steps: 78
# Episode: 8	Steps: 8
# Episode: 9	Steps: 32
# Episode: 10	Steps: 8
# Episode: 11	Steps: 32
# Episode: 12	Steps: 8
# Episode: 13	Steps: 8
# Episode: 14	Steps: 90
# Episode: 15	Steps: 82
# Episode: 16	Steps: 143
# Episode: 17	Steps: 30
# Episode: 18	Steps: 8
# Episode: 19	Steps: 147
# Episode: 20	Steps: 108
# Episode: 21	Steps: 20
# Episode: 22	Steps: 8
# Episode: 23	Steps: 38
# Episode: 24	Steps: 82
# Episode: 25	Steps: 8
# Episode: 26	Steps: 8
# Episode: 27	Steps: 9
# Episode: 28	Steps: 8
# Episode: 29	Steps: 8
# Episode: 30	Steps: 122
# Episode: 31	Steps: 8
# Episode: 32	Steps: 109
# Episode: 33	Steps: 8
# Episode: 34	Steps: 8
# Episode: 35	Steps: 16
# Episode: 36	Steps: 8
# Episode: 37	Steps: 8
# Episode: 38	Steps: 8
# Episode: 39	Steps: 8
# Episode: 40	Steps: 68
# Episode: 41	Steps: 8
# Episode: 42	Steps: 1000
# Episode: 43	Steps: 8
# Episode: 44	Steps: 8
# Episode: 45	Steps: 72
# Episode: 46	Steps: 8
# Episode: 47	Steps: 8
# Episode: 48	Steps: 8
# Episode: 49	Steps: 8
# Episode: 50	Steps: 8
# Episode: 51	Steps: 16
# Episode: 52	Steps: 8
# Episode: 53	Steps: 32
# Episode: 54	Steps: 8
# Episode: 55	Steps: 8
# Episode: 56	Steps: 9
# Episode: 57	Steps: 8
# Episode: 58	Steps: 8
# Episode: 59	Steps: 8
# Episode: 60	Steps: 8
# Episode: 61	Steps: 11
# Episode: 62	Steps: 8
# Episode: 63	Steps: 8
# Episode: 64	Steps: 8
# Episode: 65	Steps: 16
# Episode: 66	Steps: 8
# Episode: 67	Steps: 8
# Episode: 68	Steps: 8
# Episode: 69	Steps: 8
# Episode: 70	Steps: 8
# Episode: 71	Steps: 12
# Episode: 72	Steps: 8
# Episode: 73	Steps: 8
# Episode: 74	Steps: 8
# Episode: 75	Steps: 8
# Episode: 76	Steps: 9
# Episode: 77	Steps: 8
# Episode: 78	Steps: 15
# Episode: 79	Steps: 8
# Episode: 80	Steps: 8
# Episode: 81	Steps: 8
# Episode: 82	Steps: 8
# Episode: 83	Steps: 20
# Episode: 84	Steps: 8
# Episode: 85	Steps: 8
# Episode: 86	Steps: 8
# Episode: 87	Steps: 8
# Episode: 88	Steps: 8
# Episode: 89	Steps: 40
# Episode: 90	Steps: 8
# Episode: 91	Steps: 8
# Episode: 92	Steps: 8
# Episode: 93	Steps: 8
# Episode: 94	Steps: 8
# Episode: 95	Steps: 8
# Episode: 96	Steps: 8
# Episode: 97	Steps: 8
# Episode: 98	Steps: 8
# Episode: 99	Steps: 8
# Episode: 100	Steps: 8
# Agent 3 / 5
# Episode: 1	Steps: 41
# Episode: 2	Steps: 201
# Episode: 3	Steps: 166
# Episode: 4	Steps: 31
# Episode: 5	Steps: 666
# Episode: 6	Steps: 1000
# Episode: 7	Steps: 143
# Episode: 8	Steps: 211
# Episode: 9	Steps: 8
# Episode: 10	Steps: 8
# Episode: 11	Steps: 8
# Episode: 12	Steps: 203
# Episode: 13	Steps: 297
# Episode: 14	Steps: 8
# Episode: 15	Steps: 48
# Episode: 16	Steps: 56
# Episode: 17	Steps: 20
# Episode: 18	Steps: 8
# Episode: 19	Steps: 8
# Episode: 20	Steps: 8
# Episode: 21	Steps: 8
# Episode: 22	Steps: 8
# Episode: 23	Steps: 8
# Episode: 24	Steps: 8
# Episode: 25	Steps: 8
# Episode: 26	Steps: 8
# Episode: 27	Steps: 8
# Episode: 28	Steps: 8
# Episode: 29	Steps: 8
# Episode: 30	Steps: 8
# Episode: 31	Steps: 56
# Episode: 32	Steps: 8
# Episode: 33	Steps: 8
# Episode: 34	Steps: 8
# Episode: 35	Steps: 8
# Episode: 36	Steps: 8
# Episode: 37	Steps: 8
# Episode: 38	Steps: 8
# Episode: 39	Steps: 10
# Episode: 40	Steps: 8
# Episode: 41	Steps: 8
# Episode: 42	Steps: 8
# Episode: 43	Steps: 10
# Episode: 44	Steps: 15
# Episode: 45	Steps: 8
# Episode: 46	Steps: 8
# Episode: 47	Steps: 8
# Episode: 48	Steps: 8
# Episode: 49	Steps: 8
# Episode: 50	Steps: 8
# Episode: 51	Steps: 8
# Episode: 52	Steps: 8
# Episode: 53	Steps: 9
# Episode: 54	Steps: 8
# Episode: 55	Steps: 8
# Episode: 56	Steps: 167
# Episode: 57	Steps: 8
# Episode: 58	Steps: 8
# Episode: 59	Steps: 8
# Episode: 60	Steps: 8
# Episode: 61	Steps: 16
# Episode: 62	Steps: 8
# Episode: 63	Steps: 8
# Episode: 64	Steps: 8
# Episode: 65	Steps: 8
# Episode: 66	Steps: 8
# Episode: 67	Steps: 8
# Episode: 68	Steps: 8
# Episode: 69	Steps: 8
# Episode: 70	Steps: 60
# Episode: 71	Steps: 8
# Episode: 72	Steps: 8
# Episode: 73	Steps: 176
# Episode: 74	Steps: 8
# Episode: 75	Steps: 8
# Episode: 76	Steps: 8
# Episode: 77	Steps: 8
# Episode: 78	Steps: 8
# Episode: 79	Steps: 8
# Episode: 80	Steps: 10
# Episode: 81	Steps: 10
# Episode: 82	Steps: 18
# Episode: 83	Steps: 306
# Episode: 84	Steps: 8
# Episode: 85	Steps: 8
# Episode: 86	Steps: 8
# Episode: 87	Steps: 8
# Episode: 88	Steps: 8
# Episode: 89	Steps: 8
# Episode: 90	Steps: 8
# Episode: 91	Steps: 8
# Episode: 92	Steps: 14
# Episode: 93	Steps: 8
# Episode: 94	Steps: 8
# Episode: 95	Steps: 8
# Episode: 96	Steps: 8
# Episode: 97	Steps: 8
# Episode: 98	Steps: 8
# Episode: 99	Steps: 55
# Episode: 100	Steps: 8
# Agent 4 / 5
# Episode: 1	Steps: 277
# Episode: 2	Steps: 72
# Episode: 3	Steps: 15
# Episode: 4	Steps: 163
# Episode: 5	Steps: 148
# Episode: 6	Steps: 119
# Episode: 7	Steps: 14
# Episode: 8	Steps: 106
# Episode: 9	Steps: 88
# Episode: 10	Steps: 136
# Episode: 11	Steps: 9
# Episode: 12	Steps: 95
# Episode: 13	Steps: 9
# Episode: 14	Steps: 8
# Episode: 15	Steps: 172
# Episode: 16	Steps: 8
# Episode: 17	Steps: 75
# Episode: 18	Steps: 8
# Episode: 19	Steps: 8
# Episode: 20	Steps: 93
# Episode: 21	Steps: 8
# Episode: 22	Steps: 8
# Episode: 23	Steps: 188
# Episode: 24	Steps: 8
# Episode: 25	Steps: 140
# Episode: 26	Steps: 404
# Episode: 27	Steps: 8
# Episode: 28	Steps: 8
# Episode: 29	Steps: 8
# Episode: 30	Steps: 232
# Episode: 31	Steps: 8
# Episode: 32	Steps: 8
# Episode: 33	Steps: 200
# Episode: 34	Steps: 8
# Episode: 35	Steps: 8
# Episode: 36	Steps: 8
# Episode: 37	Steps: 10
# Episode: 38	Steps: 22
# Episode: 39	Steps: 144
# Episode: 40	Steps: 8
# Episode: 41	Steps: 8
# Episode: 42	Steps: 8
# Episode: 43	Steps: 8
# Episode: 44	Steps: 8
# Episode: 45	Steps: 8
# Episode: 46	Steps: 132
# Episode: 47	Steps: 8
# Episode: 48	Steps: 8
# Episode: 49	Steps: 8
# Episode: 50	Steps: 8
# Episode: 51	Steps: 8
# Episode: 52	Steps: 48
# Episode: 53	Steps: 8
# Episode: 54	Steps: 20
# Episode: 55	Steps: 8
# Episode: 56	Steps: 8
# Episode: 57	Steps: 72
# Episode: 58	Steps: 8
# Episode: 59	Steps: 8
# Episode: 60	Steps: 8
# Episode: 61	Steps: 8
# Episode: 62	Steps: 8
# Episode: 63	Steps: 64
# Episode: 64	Steps: 20
# Episode: 65	Steps: 8
# Episode: 66	Steps: 8
# Episode: 67	Steps: 8
# Episode: 68	Steps: 8
# Episode: 69	Steps: 52
# Episode: 70	Steps: 8
# Episode: 71	Steps: 8
# Episode: 72	Steps: 8
# Episode: 73	Steps: 60
# Episode: 74	Steps: 8
# Episode: 75	Steps: 8
# Episode: 76	Steps: 10
# Episode: 77	Steps: 46
# Episode: 78	Steps: 8
# Episode: 79	Steps: 8
# Episode: 80	Steps: 40
# Episode: 81	Steps: 16
# Episode: 82	Steps: 8
# Episode: 83	Steps: 8
# Episode: 84	Steps: 8
# Episode: 85	Steps: 56
# Episode: 86	Steps: 8
# Episode: 87	Steps: 8
# Episode: 88	Steps: 18
# Episode: 89	Steps: 30
# Episode: 90	Steps: 8
# Episode: 91	Steps: 8
# Episode: 92	Steps: 8
# Episode: 93	Steps: 8
# Episode: 94	Steps: 20
# Episode: 95	Steps: 8
# Episode: 96	Steps: 52
# Episode: 97	Steps: 8
# Episode: 98	Steps: 8
# Episode: 99	Steps: 8
# Episode: 100	Steps: 8
# Agent 5 / 5
# Episode: 1	Steps: 202
# Episode: 2	Steps: 56
# Episode: 3	Steps: 33
# Episode: 4	Steps: 49
# Episode: 5	Steps: 94
# Episode: 6	Steps: 98
# Episode: 7	Steps: 58
# Episode: 8	Steps: 34
# Episode: 9	Steps: 124
# Episode: 10	Steps: 8
# Episode: 11	Steps: 8
# Episode: 12	Steps: 8
# Episode: 13	Steps: 9
# Episode: 14	Steps: 11
# Episode: 15	Steps: 93
# Episode: 16	Steps: 8
# Episode: 17	Steps: 8
# Episode: 18	Steps: 8
# Episode: 19	Steps: 8
# Episode: 20	Steps: 70
# Episode: 21	Steps: 8
# Episode: 22	Steps: 45
# Episode: 23	Steps: 9
# Episode: 24	Steps: 8
# Episode: 25	Steps: 94
# Episode: 26	Steps: 8
# Episode: 27	Steps: 8
# Episode: 28	Steps: 8
# Episode: 29	Steps: 136
# Episode: 30	Steps: 44
# Episode: 31	Steps: 9
# Episode: 32	Steps: 8
# Episode: 33	Steps: 8
# Episode: 34	Steps: 255
# Episode: 35	Steps: 8
# Episode: 36	Steps: 8
# Episode: 37	Steps: 8
# Episode: 38	Steps: 8
# Episode: 39	Steps: 20
# Episode: 40	Steps: 8
# Episode: 41	Steps: 8
# Episode: 42	Steps: 8
# Episode: 43	Steps: 84
# Episode: 44	Steps: 8
# Episode: 45	Steps: 8
# Episode: 46	Steps: 8
# Episode: 47	Steps: 32
# Episode: 48	Steps: 8
# Episode: 49	Steps: 8
# Episode: 50	Steps: 8
# Episode: 51	Steps: 83
# Episode: 52	Steps: 8
# Episode: 53	Steps: 8
# Episode: 54	Steps: 8
# Episode: 55	Steps: 8
# Episode: 56	Steps: 8
# Episode: 57	Steps: 8
# Episode: 58	Steps: 8
# Episode: 59	Steps: 25
# Episode: 60	Steps: 8
# Episode: 61	Steps: 40
# Episode: 62	Steps: 8
# Episode: 63	Steps: 35
# Episode: 64	Steps: 48
# Episode: 65	Steps: 60
# Episode: 66	Steps: 8
# Episode: 67	Steps: 8
# Episode: 68	Steps: 8
# Episode: 69	Steps: 8
# Episode: 70	Steps: 8
# Episode: 71	Steps: 49
# Episode: 72	Steps: 8
# Episode: 73	Steps: 8
# Episode: 74	Steps: 8
# Episode: 75	Steps: 8
# Episode: 76	Steps: 28
# Episode: 77	Steps: 10
# Episode: 78	Steps: 8
# Episode: 79	Steps: 26
# Episode: 80	Steps: 8
# Episode: 81	Steps: 8
# Episode: 82	Steps: 28
# Episode: 83	Steps: 8
# Episode: 84	Steps: 8
# Episode: 85	Steps: 8
# Episode: 86	Steps: 19
# Episode: 87	Steps: 8
# Episode: 88	Steps: 25
# Episode: 89	Steps: 8
# Episode: 90	Steps: 8
# Episode: 91	Steps: 8
# Episode: 92	Steps: 8
# Episode: 93	Steps: 68
# Episode: 94	Steps: 8
# Episode: 95	Steps: 8
# Episode: 96	Steps: 8
# Episode: 97	Steps: 8
# Episode: 98	Steps: 8
# Episode: 99	Steps: 60
# Episode: 100	Steps: 8

# %%
# Create a figure with subplots for each pair
fig, axes = plt.subplots(len(agents_arr), 2, figsize=(8, 3*len(agents_arr)))

for i in range(len(agents_arr)):
    scores = scores_arr[i]  # Access the scores for the current agent
    durations = durations_arr[i]  # Access the durations for the current agent

    # Print information before each pair of subplots
    print("Agent", i+1, "steps stats:", "\tAverage", np.mean(durations), "\tStd dev", round(np.std(durations), 2), "\tMedian", np.median(durations))

    # Define the axes for the current agent's pair of subplots
    ax_scores = axes[i, 0]
    ax_durations = axes[i, 1]

    # Plot the scores in the first subplot
    ax_scores.plot(np.arange(len(scores)), scores)
    ax_scores.set_ylabel('Score')
    ax_scores.set_xlabel('Episode #')
    ax_scores.set_title(f'Agent {i+1} - Scores')

    # Plot the durations in the second subplot
    ax_durations.plot(np.arange(len(durations)), durations, 'r')
    ax_durations.set_ylabel('Steps')
    ax_durations.set_xlabel('Episode #')
    ax_durations.set_title(f'Agent {i+1} - Durations')

# Adjust layout for better readability
plt.tight_layout()

# Show the combined plot
plt.show()
# Out:
# Agent 1 steps stats: 	Average 39.75 	Std dev 104.64 	Median 8.0
# Agent 2 steps stats: 	Average 45.83 	Std dev 133.29 	Median 8.0
# Agent 3 steps stats: 	Average 45.91 	Std dev 129.3 	Median 8.0
# Agent 4 steps stats: 	Average 41.59 	Std dev 66.88 	Median 8.0
# Agent 5 steps stats: 	Average 27.59 	Std dev 40.31 	Median 8.0

# %%
"""n_rows, n_cols = env.unwrapped.num_rows, env.unwrapped.num_cols

n=0
for col in range(n_cols):
    for row in range(n_rows):
        n+=1
        state = np.array([row,col])
        state = torch.from_numpy(np.array(state)).float().unsqueeze(0).to(device)
        agent.qnetwork_local.eval()
        with torch.no_grad():
            action_values = agent.qnetwork_local(state)
        print(n," State: ",state.cpu().data.numpy(),"Action values: ",action_values.cpu().data.numpy())"""
# Out:
# 'n_rows, n_cols = env.unwrapped.num_rows, env.unwrapped.num_cols\n\nn=0\nfor col in range(n_cols):\n    for row in range(n_rows):\n        n+=1\n        state = np.array([row,col])\n        state = torch.from_numpy(np.array(state)).float().unsqueeze(0).to(device)\n        agent.qnetwork_local.eval()\n        with torch.no_grad():\n            action_values = agent.qnetwork_local(state)\n        print(n," State: ",state.cpu().data.numpy(),"Action values: ",action_values.cpu().data.numpy())'

# %%
def create_grids(agent, env):
    from collections import defaultdict

    n_rows, n_cols = env.unwrapped.num_rows, env.unwrapped.num_cols

    state_value = defaultdict(float)
    policy = defaultdict(int)

    for col in range(n_cols):
        for row in range(n_rows):
            state = torch.from_numpy(np.array([row,col])).float().unsqueeze(0).to(device)
            with torch.no_grad():
                action_values = agent.qnetwork_local(state)
            obs = (row, col)
            state_value[obs] = float(np.max(action_values.cpu().data.numpy()[0]))
            policy[obs] = int(np.argmax(action_values.cpu().data.numpy()[0]))

            #print(" State: ",state.cpu().data.numpy()[0],"Action values: ",action_values.cpu().data.numpy()[0])
            #print(" State value: ",state_value[state],"Policy: ",policy[state])

    # create a grid for the state values
    value_grid = np.zeros((n_rows, n_cols))
    for obs, value in state_value.items():
        value_grid[obs] = value

    # create a grid for the policy. In each state we should show the action that has the highest int(np.argmax(action_values))
    policy_grid = np.zeros((n_rows, n_cols))
    for obs, action in policy.items():
        policy_grid[obs] = action

    string_policy_grid = np.chararray((n_rows, n_cols), unicode=True)
    for i in range(5):
        for j in range(5):
            #Grid positions [0,2], [1,2], [3,2], [4,2] are walls, so we dont want to show an action for them, instead show an X. 
            #We also dont want to show an action for the goal, so we show a G in the grid position [0,4]
            if j == 2 and (i == 0 or i == 1 or i == 3 or i == 4):
                string_policy_grid[i][j] = 'X'
            elif i == 0 and j == 4:
                string_policy_grid[i][j] = 'G'
            elif policy_grid[i][j] == 0:
                string_policy_grid[i][j] = '↑'
            elif policy_grid[i][j] == 1:
                string_policy_grid[i][j] = '↓'
            elif policy_grid[i][j] == 2:
                string_policy_grid[i][j] = '←'
            elif policy_grid[i][j] == 3:
                string_policy_grid[i][j] = '→'
            else:
                string_policy_grid[i][j] = 'X'
    #print(string_policy_grid)

    return value_grid, policy_grid, string_policy_grid

# %%
def plot_string_policy(string_policy_grid):
    from matplotlib.colors import ListedColormap
    from matplotlib.patches import Patch

    map_data = np.array(string_policy_grid)
    
    colors = ['red', 'black', 'lightgreen', 'green', 'gray']
    cmap = ListedColormap(colors)

    # Create an array of integers based on the character array
    numeric_map = np.zeros(map_data.shape, dtype=int)
    for i, char in enumerate(['↓', 'X', '→', 'G', '↑']):
        numeric_map[map_data == char] = i

    # Create the plot using imshow
    fig, ax = plt.subplots()
    im = ax.imshow(numeric_map, cmap=cmap, norm=plt.Normalize(0, len(colors)))

    # Add character annotations
    for i in range(map_data.shape[0]):
        for j in range(map_data.shape[1]):
            char = map_data[i, j]
            ax.text(j, i, char, ha='center', va='center', color='black', fontsize=12)

    # add a legend
    legend_elements = [
        Patch(facecolor="gray", edgecolor="black", label="Up"),
        Patch(facecolor="red", edgecolor="black", label="Down"),
        Patch(facecolor="blue", edgecolor="black", label="Left"),
        Patch(facecolor="lightgreen", edgecolor="black", label="Right"),
        Patch(facecolor="green", edgecolor="black", label="Goal"),
    ]
    ax.legend(handles=legend_elements, bbox_to_anchor=(1.3, 1))

    return fig

# %%
value_grids = []
policy_grids = []
string_policy_grids = []

for agent in agents_arr:
    value_grid, policy_grid, string_policy_grid = create_grids(agent, env)
    value_grids.append(value_grid)
    policy_grids.append(policy_grid)
    string_policy_grids.append(string_policy_grid)

# %%
for i in range(len(agents_arr)):
    #print("Agent", i+1, "value grid:")
    #print(value_grids[i])
    #print("Agent", i+1, "policy grid:")
    #print(policy_grids[i])
    #print("Agent", i+1, "policy grid string:")
    #print(string_policy_grids[i])
    fig = plot_string_policy(string_policy_grids[i])
    fig.suptitle(f'Agent {i+1} - Policy')
plt.show()

# %%
from IPython import display

#load the weights from file
agent_replay = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
agent_replay.qnetwork_local.load_state_dict(torch.load('checkpoint.pth'))

for i in range(3):
    state = env.reset()
    img = plt.imshow(env.render(mode='rgb_array'))
    for j in range(200):
        action = agent_replay.act(state)
        img.set_data(env.render(mode='rbg_array'))
        plt.axix('off')
        display.display(plt.gcf())
        display.clear_output(wait=True)
        state,reward,done,_ = env.step(action)
        if done:
            break

env.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\el_sa\Desktop\proyectoNN_salva\DQN\train&replay.ipynb Cell 13 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/DQN/train%26replay.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> #load the weights from file
#       <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/DQN/train%26replay.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> agent_replay = Agent(state_size=env.observation_space.shape[0],action_size=env.action_space.n,seed=0)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/DQN/train%26replay.ipynb#X12sZmlsZQ%3D%3D?line=4'>5</a> agent_replay.qnetwork_local.load_state_dict(torch.load('checkpoint.pth'))
#       <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/DQN/train%26replay.ipynb#X12sZmlsZQ%3D%3D?line=6'>7</a> for i in range(3):
#       <a href='vscode-notebook-cell:/c%3A/Users/el_sa/Desktop/proyectoNN_salva/DQN/train%26replay.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a>     state = env.reset()
#
# File c:\Users\el_sa\anaconda3\envs\TFG\Lib\site-packages\torch\serialization.py:986, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     983 if 'encoding' not in pickle_load_args.keys():
#     984     pickle_load_args['encoding'] = 'utf-8'
# --> 986 with _open_file_like(f, 'rb') as opened_file:
#     987     if _is_zipfile(opened_file):
#     988         # The zipfile reader is going to advance the current file position.
#     989         # If we want to actually tail call to torch.jit.load, we need to
#     990         # reset back to the original position.
#     991         orig_position = opened_file.tell()
#
# File c:\Users\el_sa\anaconda3\envs\TFG\Lib\site-packages\torch\serialization.py:435, in _open_file_like(name_or_buffer, mode)
#     433 def _open_file_like(name_or_buffer, mode):
#     434     if _is_path(name_or_buffer):
# --> 435         return _open_file(name_or_buffer, mode)
#     436     else:
#     437         if 'w' in mode:
#
# File c:\Users\el_sa\anaconda3\envs\TFG\Lib\site-packages\torch\serialization.py:416, in _open_file.__init__(self, name, mode)
#     415 def __init__(self, name, mode):
# --> 416     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint.pth'
