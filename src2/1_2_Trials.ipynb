# %%
import sys
sys.path.append('../')

from envs.GridMaps import maze5x5, maze14x14
from utilities.transitionDatasetGeneration import *

# %%
probMapper(maze5x5["maze"], 9, higher_threshold=50.0, lower_threshold=49.9)
# Out:
# Loading models...
# Models loaded
