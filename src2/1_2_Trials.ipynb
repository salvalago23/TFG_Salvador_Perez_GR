# %%
import sys
sys.path.append('../')

from envs.GridMaps import maze5x5_withX, maze14x14_withX
from utilities.transitionDatasetGeneration import *

# %%
probMapper(maze14x14_withX, 11, higher_threshold=50.0)
# Out:
# Loading models...
# Models loaded
